# %% [markdown]
# # <p style="background-color:#FFC0CB;font-family:newtimeroman;color:black;font-size:200%;text-align:center;border-radius:10px 10px;"> !! 📉 Mohamed Hamed 📊 !! </p>

# %% [markdown]
# # <p style="background-color:#9c6644;font-family:newtimeroman;color:black;font-size:140%;text-align:center;border-radius:10px 10px;"> Overview </p>

# %% [markdown]
# # Welcome to Your Coding Journey ☕
#
# <div style="display: flex; align-items: flex-start; gap: 40px;">
#
# <div style="flex: 0 0 45%;">
#
# ![Coffee and Code](https://github.com/MohamedHamedEL-Sayed/Data-Analytics-Using-Excel-/blob/main/cozy-coding-session-stockcake.webp?raw=true)
#
# </div>
#
# <div style="flex: 1;">
#
# ## Coffee & Code: A Developer's Tale
#
# Just like the perfect cup of coffee fuels your morning, every line of code fuels your passion for building amazing things.
#
# > "This coffee is making me awesome" - Every Developer Ever
#
# ---
#
# ## 📊 Coffee & Code Survey Summary
#
# ### Key Insights from 100+ Developers in Lebanon
#
# **Coding Habits:**
# - 🕐 Average coding hours: **7-8 hours per day**
# - ☕ Average coffee cups: **2-4 cups per day**
# - 💪 Most developers code **while drinking coffee** (60%+)
#
# **Coffee Preferences:**
# - 🏆 Top choices: **Nescafe, American Coffee & Turkish**
# - ⏰ Preferred timing: **While coding** (majority preference)
# - ✅ Coffee helps solve bugs: **60% say Yes/Sometimes**
#
# **Developer Profile:**
# - 👥 Majority: **Male developers (70%+)**
# - 🎂 Age group: **18-29 years old (dominant)**
# - 📍 Location: **100% from Lebanon**
# - 🔧 Can code without coffee?: **Mixed opinions**
#
# ### The Bottom Line
# Coffee isn't just a drink—it's a developer's best friend! Whether it's Nescafe or Turkish coffee, developers know that the right brew makes the code flow better.
#
# ---
#
# **Let's build amazing things, one cup at a time!** ☕💻
#
# Welcome aboard! ✨
#
# </div>
#
# </div>

# %% [markdown]
# # <p style="background-color:#c9ada7;font-family:newtimeroman;color:black;font-size:140%;text-align:center;border-radius:10px 10px;"> LIBRARY </p>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("C:/Users/FreeComp/Downloads/Coffee Code Analyst/Data Analyst Coffee/Data Coffee.csv")
data.head(5)
# Out:
#    CodingHours  CoffeeCupsPerDay     CoffeeTime CodingWithoutCoffee  \
# 0            8                 2  Before coding                 Yes
# 1            3                 2  Before coding                 Yes
# 2            5                 3   While coding                  No
# 3            8                 2  Before coding                  No
# 4           10                 3   While coding           Sometimes
#
#     CoffeeType CoffeeSolveBugs  Gender  Country  AgeRange
# 0  Caffè latte       Sometimes  Female  Lebanon  18 to 29
# 1    Americano             Yes  Female  Lebanon  30 to 39
# 2      Nescafe             Yes  Female  Lebanon  18 to 29
# 3      Nescafe             Yes    Male  Lebanon       NaN
# 4      Turkish              No    Male  Lebanon  18 to 29

# %%
data.columns
# Out:
# Index(['CodingHours', 'CoffeeCupsPerDay', 'CoffeeTime', 'CodingWithoutCoffee',
#        'CoffeeType', 'CoffeeSolveBugs', 'Gender', 'Country', 'AgeRange'],
#       dtype='str')

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CodingHours          100 non-null    int64
#  1   CoffeeCupsPerDay     100 non-null    int64
#  2   CoffeeTime           100 non-null    str
#  3   CodingWithoutCoffee  100 non-null    str
#  4   CoffeeType           99 non-null     str
#  5   CoffeeSolveBugs      100 non-null    str
#  6   Gender               100 non-null    str
#  7   Country              100 non-null    str
#  8   AgeRange             98 non-null     str
# dtypes: int64(2), str(7)
# memory usage: 7.2 KB

# %%
sns.pairplot(data)

# %%
sns.pairplot(data, hue="Gender")

# %%
sns.pairplot(data, hue="CodingWithoutCoffee")

# %%
def count_plot(variable):
    """
       input: variable example: "CoffeeTime"
       output: count plot and value count
    """
    #get Feature
    var = data[variable]

    #Visualization 
    plt.figure(figsize=(10,4))
    sns.countplot(x=var, palette="dark",order=var.value_counts().index)
    plt.xticks(rotation=45)
    plt.ylabel("frequency")
    plt.title(variable)
    print("{}",format(var.value_counts()))
    plt.show()

# %%
categorical = ["CoffeeTime", "CodingWithoutCoffee", "CoffeeType", "CoffeeSolveBugs", "Gender", "Country", "AgeRange"]
for i in categorical:
    count_plot(i)
# Out:
# C:\Users\FreeComp\AppData\Local\Temp\ipykernel_15008\1459748685.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=var, palette="dark",order=var.value_counts().index)
# {} CoffeeTime
# While coding               61
# Before coding              25
# Before and while coding     4
# All the time                4
# In the morning              3
# After coding                2
# No specific time            1
# Name: count, dtype: int64
# {} CodingWithoutCoffee
# Sometimes    51
# Yes          30
# No           19
# Name: count, dtype: int64
# C:\Users\FreeComp\AppData\Local\Temp\ipykernel_15008\1459748685.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
data[["Gender","CoffeeCupsPerDay"]].groupby(["Gender"]).mean().sort_values(by="CoffeeCupsPerDay", ascending=False)
# Out:
#         CoffeeCupsPerDay
# Gender
# Male            3.108108
# Female          2.269231

# %%
sns.barplot(x="Gender", y="CoffeeCupsPerDay", data=data, palette="dark")
# Out:
# C:\Users\FreeComp\AppData\Local\Temp\ipykernel_15008\1770956883.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Gender", y="CoffeeCupsPerDay", data=data, palette="dark")
# <Axes: xlabel='Gender', ylabel='CoffeeCupsPerDay'>

# %% [markdown]
# <br>
# <div style="text-align: center;">
#    <span style="font-size: 4.5em; font-weight: bold; font-family: Arial;">😍THANK YOU😍</span>
# <div style="text-align: center;">
#     <span style="font-size: 2em;">Mohamed✔️Hamed</span>
